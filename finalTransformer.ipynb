# %%
print("\n--- Descargando y extrayendo NSL-KDD ---")

# !wget -q -c https://github.com/defcom17/NSL_KDD/archive/refs/heads/master.zip -O nsl_kdd.zip
# !unzip -o nsl_kdd.zip > /dev/null

print("Dataset descargado y extraído en la carpeta 'NSL_KDD-master'.")
# Out:
# --- Descargando y extrayendo NSL-KDD ---
# Dataset descargado y extraído en la carpeta 'NSL_KDD-master'.

# %%
# !nvcc transformer.cu -o mlp_executable -arch=sm_75
# !./mlp_executable
# Out:
# Train size: 125973
# Test size : 22544
# Classes   : 23
# T0 dims = 84
#
# ==== Entrenando Transformer + MLP CUDA ====
# Epoch 1 | Loss = 1.68101
# Epoch 2 | Loss = 1.2284
# Epoch 3 | Loss = 1.2106
#
# ==== Evaluando ====
# Test Accuracy = 3.50426%
# Modelo guardado en mlp_model.bin

# %%
# !nvcc average.cu -o mlp_executable -arch=sm_75
# !./mlp_executable
# Out:
# Cargando 3 modelos...
# Modelo cargado desde mlp_model_1.bin
# Modelo cargado desde mlp_model_2.bin
# Modelo cargado desde mlp_model_3.bin
# Promedio completado.
# Evaluando ensemble promedio...
# Accuracy final (ensemble) = 35.5172%
